# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib widget

# %%
electrodes = pd.read_csv('electrodes.csv')

# %%
import bluepysnap as bp
s = bp.Simulation('../hippocampusSim/simulation_config.json')
c = s.circuit

# %%
n = c.nodes['hippocampus_neurons'].get(group='cylinder300')

# %%
n1 = c.nodes['hippocampus_neurons'].get(group='Mosaic')

# %%
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
# ax.scatter(n1['x'].iloc[:1000],n1['y'].iloc[:1000],n1['z'].iloc[:1000])
ax.scatter(n['x'].iloc[:100],n['y'].iloc[:100],n['z'].iloc[:100])
ax.scatter(electrodes['x'],electrodes['y'],electrodes['z'])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
